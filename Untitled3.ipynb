# %%
import pandas as pd

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

purchases = pd.DataFrame(data)

purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])




df = pd.read_csv('Downloads/purchases.csv')

# %%
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
movie = pd.read_csv('Downloads/IMDB_Movie_Data.csv')

# %%
movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movie.rename(columns={'Runtime (Minutes)': 'Runtime', 'Revenue (Millions)': 'MillRevenue'}, inplace = True)

# %%
movie.dropna()
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
revenue = movie['MillRevenue']
revenuemean = revenue.mean()

# %%
revenue.fillna(revenuemean, inplace = True)

# %%
revenuemean
# Out:
# 82.95637614678898

# %%
import matplotlib.pyplot as plt

# %%
movie.plot(kind='scatter', x='Rating', y='MillRevenue', title='Revenue vs Rating')
# Out:
# <Axes: title={'center': 'Revenue vs Rating'}, xlabel='Rating', ylabel='MillRevenue'>

# %%
movie['Rating'].plot(kind='hist', title='Rating')
# Out:
# <Axes: title={'center': 'Rating'}, ylabel='Frequency'>
